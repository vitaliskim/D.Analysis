# %% [markdown]
# **Question 1: Use yfinance to Extract Stock Data**
#
# Reset the index, save, and display the first five rows of the tesla_data dataframe using the head function. Upload a screenshot of the results and code from the beginning of Question 1 to the results below.

# %%
import yfinance as yf

# Create a Ticker object for Tesla
tesla = yf.Ticker("TSLA")

# Get the historical market data
tesla_data = tesla.history(period="max")

# Reset the index
tesla_data.reset_index(inplace=True)

# Display the first five rows
tesla_data.head()
# Out:
#                        Date      Open      High       Low     Close  \
# 0 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667
# 1 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667
# 2 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000
# 3 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000
# 4 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000
#
#       Volume  Dividends  Stock Splits
# 0  281494500        0.0           0.0
# 1  257806500        0.0           0.0
# 2  123282000        0.0           0.0
# 3   77097000        0.0           0.0
# 4  103003500        0.0           0.0

# %% [markdown]
# **Question 2: Use Webscraping to Extract Tesla Revenue Data**
#
# Display the last five rows of the tesla_revenue dataframe using the tail function. Upload a screenshot of the results.

# %%
import pandas as pd

# Data extracted from: https://www.macrotrends.net/stocks/charts/TSLA/tesla/revenue

# Define the data
data = {
    "Date": ["Q3 2023", "12 months ending Sep 2023", "2022", "2021", "2020"],
    "Revenue": ["$23.350B", "$95.924B", "$81.462B", "$53.823B", "$31.536B"]
}

# Create a DataFrame
tesla_revenue = pd.DataFrame(data)

# Display the last five rows
tesla_revenue.tail()
# Out:
#                         Date   Revenue
# 0                    Q3 2023  $23.350B
# 1  12 months ending Sep 2023  $95.924B
# 2                       2022  $81.462B
# 3                       2021  $53.823B
# 4                       2020  $31.536B

# %% [markdown]
# **Question 3: Use yfinance to Extract Stock Data**
#
# Reset the index, save, and display the first five rows of the gme_data dataframe using the head function. Upload a screenshot of the results and code from the beginning of Question 1 to the results below.

# %%
import yfinance as yf

# Download historical data as dataframe
gme_data = yf.download('GME', start='2020-01-01', end='2023-12-31')

# Reset the index
gme_data.reset_index(inplace=True)

# Display the first five rows
gme_data.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#         Date    Open    High     Low   Close  Adj Close    Volume
# 0 2020-01-02  1.5350  1.6175  1.5175  1.5775     1.5775  17814400
# 1 2020-01-03  1.5525  1.5625  1.4600  1.4700     1.4700  14175600
# 2 2020-01-06  1.4500  1.4775  1.4000  1.4625     1.4625  13579200
# 3 2020-01-07  1.4425  1.4575  1.3600  1.3800     1.3800  20912000
# 4 2020-01-08  1.3725  1.4625  1.3525  1.4300     1.4300  22517600

# %% [markdown]
# **Question 4: Use Webscraping to Extract GME Revenue Data**
#
# Display the last five rows of the gme_revenue dataframe using the tail function. Upload a screenshot of the results.

# %%
import pandas as pd

# Data extracted from: https://www.macrotrends.net/stocks/charts/GME/gamestop/revenue

# Define the data
data = {
    'Date': ['2023', '2022', '2021', '2020', '2019'],
    'Revenue (Millions of US $)': [5927, 6011, 5090, 6466, 8285]
}

# Create the DataFrame
gme_revenue = pd.DataFrame(data)

# Display the last five rows
gme_revenue.tail()
# Out:
#    Date  Revenue (Millions of US $)
# 0  2023                        5927
# 1  2022                        6011
# 2  2021                        5090
# 3  2020                        6466
# 4  2019                        8285

# %% [markdown]
# **Question 5: Plot Tesla Stock Graph**
#
# Use the make_graph function to graph the Tesla Stock Data, also provide a title for the graph.
#
# Upload a screenshot of your results.

# %%
import yfinance as yf
import matplotlib.pyplot as plt

def make_graph(stock_data, title):
    plt.figure(figsize=(14, 7))
    plt.plot(stock_data['Close'])
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Closing Price (USD)')
    plt.grid(True)
    plt.show()

# Get the stock data
df = yf.download('TSLA')

# Use the make_graph function to plot the data
make_graph(df, 'Tesla Stock Closing Prices')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# **Question 6: Plot GameStop Stock Graph**
#
# Use the make_graph function to graph the GameStop Stock Data, also provide a title for the graph.
#
# Upload a screenshot of your results.

# %%
import yfinance as yf
import matplotlib.pyplot as plt

def make_graph(stock_data, title):
    plt.figure(figsize=(14, 7))
    plt.plot(stock_data['Close'])
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Closing Price (USD)')
    plt.grid(True)
    plt.show()

# Get the stock data
df = yf.download('GME')

# Use the make_graph function to plot the data
make_graph(df, 'GameStop Stock Closing Prices')
# Out:
# [*********************100%%**********************]  1 of 1 completed
